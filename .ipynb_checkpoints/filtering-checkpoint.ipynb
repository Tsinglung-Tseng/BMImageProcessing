# %%
# %matplotlib inline
import numpy as np
from skimage import data, filters
import matplotlib.pyplot as plt
from filtering import Image, Kernel, convolution

camera = data.camera()
plt.imshow(camera, cmap='gray')
# Out:
# /Users/tsinglung/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
c_i = Image(camera)
r = convolution(c_i, Kernel(ktype='roberts'))

# %%
plt.imshow(r, cmap='gray')
